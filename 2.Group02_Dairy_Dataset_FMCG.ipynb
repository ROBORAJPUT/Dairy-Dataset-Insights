# %% [markdown]
# # Name of the Participants:-
# ##  1. Nabil Tahwildar
# ##  2. Rohit Rajput
# ##  3. Akash Ghodake

# %% [markdown]
# # Description:-
# The Dairy Goods Sales Dataset provides a detailed and comprehensive collection of data related to dairy farms, dairy products, sales, and inventory management. This dataset encompasses a wide range of information, including farm location, land area, cow population, farm size, production dates, product details, brand information, quantities, pricing, shelf life, storage conditions, expiration dates, sales information, customer locations, sales channels, stock quantities, stock thresholds, and reorder quantities.

# %% [markdown]
# # Phase 1 Question (Description 10 Questions)
# * Q1. Find the all location of total land area.
# * Q2. Convert Location and Brand variables from dairy_data dataset into upper case.
# * Q3. How many unique brands are there, and what is the average price per unit for each brand?
# * Q4. What is the total revenue generated from products with a shelf life of less than 30 days?
# * Q5. Calculate the total price per unit of 'Sudha' brand milk products that are stored in 'Tetra Pack' containers.
# * Q6. Could you please share the line chart you've created to visualize the overall monthly Revenue trend?
# * Q7. To create a Bar chart that compares the sales trends of 'Sudha' products between 2019 to 2022.
# * Q8. Can you provide a summary of sales for 'Warana' products for the years 2019, 2020, 2021, and 2022 and create bar chart?
# * Q9. To visualize the total sales data for "Warana" and "Passion Cheese" products over the years 2019 to 2022 in a line chart.
# * Q10. How much year growth rate-Sales has been improved (CAGR) per  location for all brand.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

dairy_data = pd.read_excel("C:\\Users\\hp\Downloads\\2.Group02_ Dairy_Dataset_FMCG.xlsx")
dairy_data
# Out:
#            Location  Total Land Area (acres)  Number of Cows Farm Size  \
# 0         Telangana                   310.84              96    Medium
# 1     Uttar Pradesh                    19.19              44     Large
# 2        Tamil Nadu                   581.69              24    Medium
# 3         Telangana                   908.00              89     Small
# 4       Maharashtra                   861.95              21    Medium
# ...             ...                      ...             ...       ...
# 4320          Delhi                   748.71              89    Medium
# 4321      Jharkhand                   385.91              29     Large
# 4322     Chandigarh                   311.54              65     Small
# 4323    Maharashtra                   890.55              90     Small
# 4324      Rajasthan                   492.86              58     Large
#
#            Date  Product ID Product Name                 Brand  \
# ...

# %%
dairy_data.columns
# Out:
# Index(['Location', 'Total Land Area (acres)', 'Number of Cows', 'Farm Size',
#        'Date', 'Product ID', 'Product Name', 'Brand', 'Quantity (liters/kg)',
#        'Price per Unit', 'Total Value', 'Shelf Life (days)',
#        'Storage Condition', 'Production Date', 'Expiration Date',
#        'Quantity Sold (liters/kg)', 'Price per Unit (sold)',
#        'Approx. Total Revenue(INR)', 'Customer Location', 'Sales Channel',
#        'Quantity in Stock (liters/kg)', 'Minimum Stock Threshold (liters/kg)',
#        'Reorder Quantity (liters/kg)'],
#       dtype='object')

# %% [markdown]
# # 1. Find total land area for each location.

# %%
# Hint:.
#  Group by the "Location" column. Then, select the "Total Land Area (acres)" column within each group,
# and calculate the sum of values within each group.
to_grp = dairy_data.groupby("Location")["Total Land Area (acres)"].sum().reset_index()

# Display the resulting DataFrame 'to_grp'.
to_grp
# Out:
#           Location  Total Land Area (acres)
# 0            Bihar                123740.88
# 1       Chandigarh                262496.66
# 2            Delhi                267502.01
# 3          Gujarat                131749.37
# 4          Haryana                121921.57
# 5        Jharkhand                123127.74
# 6        Karnataka                129767.96
# 7           Kerala                128608.08
# 8   Madhya Pradesh                135883.88
# 9      Maharashtra                124371.52
# 10       Rajasthan                124122.54
# 11      Tamil Nadu                120402.22
# 12       Telangana                122481.88
# 13   Uttar Pradesh                144035.27
# 14     West Bengal                117352.71

# %% [markdown]
# # 2. Convert Location and Brand variables from dairy_data dataset into upper case.

# %%
# Hint:.
# Use the applymap() function to transform specific columns in the 'dairy_data' DataFrame.
# For the 'Location' and 'Brand' columns, apply the lambda function to each cell.
# If the cell value is a string (str), convert it to uppercase using the upper() method.
# If the cell value is not a string (e.g., numeric or other data types), leave it unchanged.

dairy_data[['Location', 'Brand']] = dairy_data[['Location', 'Brand']].applymap(lambda x: x.upper() if isinstance(x, str) else x)

# Display the modified 'dairy_data' DataFrame.
dairy_data
# Out:
#            Location  Total Land Area (acres)  Number of Cows Farm Size  \
# 0         TELANGANA                   310.84              96    Medium
# 1     UTTAR PRADESH                    19.19              44     Large
# 2        TAMIL NADU                   581.69              24    Medium
# 3         TELANGANA                   908.00              89     Small
# 4       MAHARASHTRA                   861.95              21    Medium
# ...             ...                      ...             ...       ...
# 4320          DELHI                   748.71              89    Medium
# 4321      JHARKHAND                   385.91              29     Large
# 4322     CHANDIGARH                   311.54              65     Small
# 4323    MAHARASHTRA                   890.55              90     Small
# 4324      RAJASTHAN                   492.86              58     Large
#
#            Date  Product ID Product Name                 Brand  \
# ...

# %% [markdown]
# # 3. How many unique brands are there, and what is the average price per unit for each brand?

# %%
# Hint:.
# Get the unique values in the 'Brand' column and store them in the 'unique_Brand' variable.
unique_Brand = dairy_data['Brand'].unique()
unique_Brand

# Group the 'dairy_data' DataFrame by the 'Brand' column and calculate the mean of the 'Price per Unit' for each brand.
Brand_avg_prc= dairy_data.groupby('Brand')['Price per Unit'].mean().round(2)
Brand_avg_prc

# Print the number of unique brands by getting the length of the 'unique_Brand' array.
print("Number of Unique Brands:", len(unique_Brand))

#Print a message and the average price per unit for each brand.
print("Average Price per Unit for Each Brand:")
print(Brand_avg_prc)
# Out:
# Number of Unique Brands: 11
# Average Price per Unit for Each Brand:
# Brand
# Amul                    54.48
# Britannia Industries    51.08
# Dodla Dairy             54.09
# Dynamix Dairies         56.49
# Mother Dairy            54.35
# Palle2patnam            52.28
# Parag Milk Foods        59.60
# Passion Cheese          55.64
# Raj                     55.53
# Sudha                   55.06
# Warana                  58.01
# Name: Price per Unit, dtype: float64

# %% [markdown]
# # 4. What is the total revenue generated from products with a shelf life of less than 30 days?

# %%
#Hint:.
# Set the shelf life to 30 days.
shelf_life = 30

# Filter the 'dairy_data' DataFrame to select rows where 'Shelf Life (days)' is less than the specified shelf life threshold.
filtered_data_loc = dairy_data.loc[dairy_data['Shelf Life (days)'] < shelf_life]
filtered_data_loc

# Calculate the total revenue by summing the 'Approx. Total Revenue(INR)' column in the filtered data.
total_revenue_loc = filtered_data_loc['Approx. Total Revenue(INR)'].sum().round(2)
total_revenue_loc

# Print a message indicating the total revenue from products with a shelf life of less than 30 days.
print("Total revenue from products with a shelf life of less than 30 days:", total_revenue)
# Out:
# Total revenue from products with a shelf life of less than 30 days: 42777072.82

# %% [markdown]
# # 5. Calculate the total price per unit of 'Sudha' brand milk products that are stored in 'Tetra Pack' containers.

# %%
# Hint:.
# Use the .loc[] method to filter the 'dairy_data' DataFrame based on multiple conditions.
# The conditions are: 1. 'Product Name' is 'Milk', 2. 'Brand' is 'Sudha', 3. 'Storage Condition' is 'Tetra Pack'
# Then, select the 'Price per Unit' column and calculate the sum of its values.
Result = dairy_data.loc[(dairy_data['Product Name'] == 'Milk') & (dairy_data['Brand'] == 'Sudha') & (dairy_data['Storage Condition'] == "Tetra Pack"), 'Price per Unit'].sum()

# Display the result, which is the sum of 'Price per Unit' for the specified conditions.
Result
# Out:
# 2655.81

# %% [markdown]
# # 6. Give the appropriate chart you've created to visualize the overall monthly Revenue trend?

# %%
# Hint:.
# Create a new column 'Month_year' in the 'dairy_data' DataFrame by applying a lambda function to format the 'Production Date' column as '%Y-%m'.
dairy_data['Month_year'] = dairy_data['Production Date'].apply(lambda x : x.strftime('%Y-%m'))
dairy_data

# Group the 'dairy_data' DataFrame by the 'Month_year' column and calculate the sum of 'Approx. Total Revenue(INR)' for each month-year.
dd = dairy_data.groupby('Month_year')['Approx. Total Revenue(INR)'].sum().reset_index()
dd

# Create a plot with matplotlib to visualize the monthly revenue trends.
plt.figure(figsize=(16, 5))
plt.plot(dd['Month_year'], dd['Approx. Total Revenue(INR)'], marker = 'o', color='#0000FF')

# Customize the x-axis labels by rotating them vertically and adjusting the label size.
plt.xticks(rotation='vertical', size=8)
plt.title("Monthly Revenue Trend")
plt.xlabel("Month_year")
plt.ylabel("Approx. Total Revenue(INR)")

# Show the plot.
plt.show()

# Why we use line chart:-  This type of data reveals trends, patterns, and seasonality, making it perfect for line charts.

# %% [markdown]
# # 7. To create a Bar chart that compares the sales trends of 'Sudha' products between 2019 to 2022.

# %%
# Hint:.

# Create a new column 'Year' in the 'dairy_data' DataFrame by extracting the year from the 'Date' column.
dairy_data["Year"] = dairy_data['Date'].dt.year

# Display the modified 'dairy_data' DataFrame with the new 'Year' column.
dairy_data

# Filter the 'dairy_data' DataFrame to select rows where the 'Brand' is 'Sudha'.
Sudha = dairy_data[dairy_data['Brand'] == 'Sudha']

# Group the Sudha data by 'Brand' and calculate the sum of 'Approx. Total Revenue(INR)' for Sudha products.
Sudha.groupby('Brand')['Approx. Total Revenue(INR)'].sum()

# Filter the Sudha data for the year 2019.
Sudha19 = Sudha[Sudha['Year'] == 2019]

# Group the 2019 Sudha data by 'Product Name' and calculate the sum of 'Approx. Total Revenue(INR)'.
Sudha_19 = Sudha19.groupby('Product Name')['Approx. Total Revenue(INR)'].sum().reset_index()
Sudha_19

# Calculate the total sales for Sudha products in 2019.
total_sale_Sudha_19 = Sudha19['Approx. Total Revenue(INR)'].sum().round(2)

# Filter the Sudha data for the year 2020.
Sudha20 = Sudha[Sudha['Year'] == 2020]

# Group the 2020 Sudha data by 'Product Name' and calculate the sum of 'Approx. Total Revenue(INR)'.
Sudha_20 = Sudha20.groupby('Product Name')['Approx. Total Revenue(INR)'].sum().reset_index()
Sudha_20

# Calculate the total sales for Sudha products in 2020.
total_sale_Sudha_20 = Sudha20['Approx. Total Revenue(INR)'].sum().round(2)

# Filter the Sudha data for the year 2021.
Sudha21 = Sudha[Sudha['Year'] == 2021]

# Group the 2021 Sudha data by 'Product Name' and calculate the sum of 'Approx. Total Revenue(INR)'.
Sudha_21 = Sudha21.groupby('Product Name')['Approx. Total Revenue(INR)'].sum().reset_index()
Sudha_21

# Calculate the total sales for Sudha products in 2021.
total_sale_Sudha_21 = Sudha21['Approx. Total Revenue(INR)'].sum().round(2)

# Filter the Sudha data for the year 2022.
Sudha22 = Sudha[Sudha['Year'] == 2022]

# Group the 2022 Sudha data by 'Product Name' and calculate the sum of 'Approx. Total Revenue(INR)'.
Sudha_22 = Sudha22.groupby('Product Name')['Approx. Total Revenue(INR)'].sum().reset_index()
Sudha_22

# Calculate the total sales for Sudha products in 2022.
total_sale_Sudha_22 = Sudha22['Approx. Total Revenue(INR)'].sum().round(2)

# Merge the sales data for Sudha products in 2019 and 2020 based on 'Product Name'.
Sudha_sale_19_20 = pd.merge(Sudha_19, Sudha_20, how='inner', left_on='Product Name', right_on='Product Name')

# Rename columns to indicate sales for 2019 and 2020.
Sudha_sale_19_20 = Sudha_sale_19_20.rename(columns={'Approx. Total Revenue(INR)_x': 'sale_2019', 'Approx. Total Revenue(INR)_y': 'sale_2020'})

# Merge the sales data for Sudha products in 2021 and 2022 based on 'Product Name'.
Sudha_sale_21_22 = pd.merge(Sudha_21, Sudha_22, how='inner', left_on='Product Name', right_on='Product Name')

# Rename columns to indicate sales for 2021 and 2022.
Sudha_sale_21_22 = Sudha_sale_21_22.rename(columns={'Approx. Total Revenue(INR)_x': 'sale_2021', 'Approx. Total Revenue(INR)_y': 'sale_2022'})

# Merge the sales data for Sudha products in 2019, 2020, 2021, and 2022 based on 'Product Name'.
Sudha_sale_19_20_21_22 = pd.merge(Sudha_sale_19_20, Sudha_sale_21_22, how='inner', left_on='Product Name', right_on='Product Name')

# Display the resulting DataFrame that contains sales data for Sudha products in different years.
Sudha_sale_19_20_21_22
# Out:
#   Product Name  sale_2019  sale_2020  sale_2021  sale_2022
# 0   Buttermilk  309547.14  292700.91  336703.65  267334.05
# 1         Curd  438278.51  408845.97  374645.50  536508.53
# 2         Ghee  446906.86  317838.05  155373.77  420058.87
# 3        Lassi  311604.29  309387.92  306536.20  398766.74
# 4         Milk  200009.78  360526.60  340426.28  259538.91
# 5       Paneer  305188.58  375274.23  427172.70  470935.52

# %%
import matplotlib.pyplot as plt

# Assuming you have already calculated the sales data for 'Sudha' products in 2019, 2020, 2021, and 2022
products = Sudha_19['Product Name']  # List of product names
sales_2019 = Sudha_19['Approx. Total Revenue(INR)']  # Sales data for 2019
sales_2020 = Sudha_20['Approx. Total Revenue(INR)']  # Sales data for 2020
sales_2021 = Sudha_21['Approx. Total Revenue(INR)']  # Sales data for 2021
sales_2022 = Sudha_22['Approx. Total Revenue(INR)']  # Sales data for 2022

# Create the bar chart for each product
plt.figure(figsize=(12, 8))  # Set the figure size

# Generate positions for the bars
x = range(len(products))

# Width of each bar
bar_width = 0.2

# Create bars for each year
plt.bar(x, sales_2019, width=bar_width, align='center', label='2019', alpha=0.7)
plt.bar([i + bar_width for i in x], sales_2020, width=bar_width, align='center', label='2020', alpha=0.7)
plt.bar([i + 2 * bar_width for i in x], sales_2021, width=bar_width, align='center', label='2021', alpha=0.7)
plt.bar([i + 3 * bar_width for i in x], sales_2022, width=bar_width, align='center', label='2022', alpha=0.7)

# Set x-axis ticks and labels
plt.xticks([i + 1.5 * bar_width for i in x], products, rotation=45, ha='right')

# Add labels and title
plt.xlabel('Product')
plt.ylabel('Revenue (INR)')
plt.title('Comparison of "Sudha" Product Sales (2019-2022)')

# Show legend
plt.legend()

# Show gridlines
plt.grid(axis='y')

# Display the bar chart
plt.tight_layout()
plt.show()

# %% [markdown]
# # 8. Can you provide a summary of sales for 'Warana' products for the years 2019, 2020, 2021, and 2022 and create bar chart?

# %%
# Hint:.

# Filter the 'dairy_data' DataFrame to select rows where the 'Brand' is 'Warana'.
Warana = dairy_data[dairy_data['Brand'] == 'Warana']

# Group the Warana data by 'Brand' and calculate the sum of 'Approx. Total Revenue(INR)' for Warana products.
Warana.groupby('Brand')['Approx. Total Revenue(INR)'].sum()

# Filter the Warana data for the year 2019.
Warana19 = Warana[Warana['Year'] == 2019]

# Group the 2019 Warana data by 'Product Name' and calculate the sum of 'Approx. Total Revenue(INR)'.
Warana_19 = Warana19.groupby('Product Name')['Approx. Total Revenue(INR)'].sum().reset_index()
Warana_19

# Calculate the total sales for Warana products in 2019.
total_sale_Warana_19 = Warana19['Approx. Total Revenue(INR)'].sum().round(2)

# Filter the Warana data for the year 2020.
Warana20 = Warana[Warana['Year'] == 2020]

# Group the 2020 Warana data by 'Product Name' and calculate the sum of 'Approx. Total Revenue(INR)'.
Warana_20 = Warana20.groupby('Product Name')['Approx. Total Revenue(INR)'].sum().reset_index()
Warana_20

# Calculate the total sales for Warana products in 2020.
total_sale_Warana_20 = Warana20['Approx. Total Revenue(INR)'].sum().round(2)

# Filter the Warana data for the year 2021.
Warana21 = Warana[Warana['Year'] == 2021]

# Group the 2021 Warana data by 'Product Name' and calculate the sum of 'Approx. Total Revenue(INR)'.
Warana_21 = Warana21.groupby('Product Name')['Approx. Total Revenue(INR)'].sum().reset_index()
Warana_21

# Calculate the total sales for Warana products in 2021.
total_sale_Warana_21 = Warana21['Approx. Total Revenue(INR)'].sum().round(2)

# Filter the Warana data for the year 2022.
Warana22 = Warana[Warana['Year'] == 2022]

# Group the 2022 Warana data by 'Product Name' and calculate the sum of 'Approx. Total Revenue(INR)'.
Warana_22 = Warana22.groupby('Product Name')['Approx. Total Revenue(INR)'].sum().reset_index()
Warana_22

# Calculate the total sales for Warana products in 2022.
total_sale_Warana_22 = Warana22['Approx. Total Revenue(INR)'].sum().round(2)

# Merge the sales data for Warana products in 2019 and 2020 based on 'Product Name'.
Warana_sale_19_20 = pd.merge(Warana_19, Warana_20, how='inner', left_on='Product Name', right_on='Product Name')

# Rename columns to indicate sales for 2019 and 2020.
Warana_sale_19_20 = Warana_sale_19_20.rename(columns={'Approx. Total Revenue(INR)_x': 'sale_2019', 'Approx. Total Revenue(INR)_y': 'sale_2020'})

# Merge the sales data for Warana products in 2021 and 2022 based on 'Product Name'.
Warana_sale_21_22 = pd.merge(Warana_21, Warana_22, how='inner', left_on='Product Name', right_on='Product Name')

# Rename columns to indicate sales for 2021 and 2022.
Warana_sale_21_22 = Warana_sale_21_22.rename(columns={'Approx. Total Revenue(INR)_x': 'sale_2021', 'Approx. Total Revenue(INR)_y': 'sale_2022'})

# Merge the sales data for Warana products in 2019, 2020, 2021, and 2022 based on 'Product Name'.
Warana_sale_19_20_21_22 = pd.merge(Warana_sale_19_20, Warana_sale_21_22, how='inner', left_on='Product Name', right_on='Product Name')

# Display the resulting DataFrame that contains sales data for Warana products in different years.
Warana_sale_19_20_21_22
# Out:
#   Product Name  sale_2019  sale_2020  sale_2021  sale_2022
# 0       Butter  584268.92   286591.1  430047.56  468597.97

# %%
# Assuming you have already calculated the sales data for 'Warana' products for each year
years = [2019, 2020, 2021, 2022]
total_sales = [total_sale_Warana_19, total_sale_Warana_20, total_sale_Warana_21, total_sale_Warana_22]

# Create a bar chart
plt.figure(figsize=(10, 6))  # Set the figure size
x = np.arange(len(years))  # x-values for the bars
bar_width = 0.35  # Width of the bars

plt.bar(x, total_sales, bar_width, label='Warana')

# Add labels and title
plt.xlabel('Year')
plt.ylabel('Total Sales (INR)')
plt.title('Total Sales for "Warana" Products (2019-2022)')

# Add data labels above the bars
for i, sales in enumerate(total_sales):
    plt.text(i, sales, str(sales), ha='center', va='bottom')

# Set x-axis ticks and labels
plt.xticks(x, years)

# Show legend
plt.legend()

# Show gridlines
plt.grid(axis='y')

# Display the bar chart
plt.show()

# %% [markdown]
# # 9. To visualize the total sales data for "Warana" and "Passion Cheese" products over the years 2019 to 2022 in a line chart.

# %%
# Hint:.
# Filter the 'dairy_data' DataFrame to select rows where the 'Brand' is 'Passion Cheese'.
Passion_Cheese = dairy_data[dairy_data['Brand'] == 'Passion Cheese']

# Group the Passion Cheese data by 'Brand' and calculate the sum of 'Approx. Total Revenue(INR)' for Passion Cheese products.
Passion_Cheese.groupby('Brand')['Approx. Total Revenue(INR)'].sum()

# Filter the Passion Cheese data for the year 2019.
Passion_Cheese19 = Passion_Cheese[Passion_Cheese['Year'] == 2019]

# Group the 2019 Passion Cheese data by 'Product Name' and calculate the sum of 'Approx. Total Revenue(INR)'.
Passion_Cheese_19 = Passion_Cheese19.groupby('Product Name')['Approx. Total Revenue(INR)'].sum().reset_index()
Passion_Cheese_19

# Calculate the total sales for Passion Cheese products in 2019.
total_sale_Passion_Cheese_19 = Passion_Cheese19['Approx. Total Revenue(INR)'].sum()

# Filter the Passion Cheese data for the year 2020.
Passion_Cheese20 = Passion_Cheese[Passion_Cheese['Year'] == 2020]

# Group the 2020 Passion Cheese data by 'Product Name' and calculate the sum of 'Approx. Total Revenue(INR)'.
Passion_Cheese_20 = Passion_Cheese20.groupby('Product Name')['Approx. Total Revenue(INR)'].sum().reset_index()
Passion_Cheese_20

# Calculate the total sales for Passion Cheese products in 2020.
total_sale_Passion_Cheese_20 = Passion_Cheese20['Approx. Total Revenue(INR)'].sum()

# Filter the Passion Cheese data for the year 2021.
Passion_Cheese21 = Passion_Cheese[Passion_Cheese['Year'] == 2021]

# Group the 2021 Passion Cheese data by 'Product Name' and calculate the sum of 'Approx. Total Revenue(INR)'.
Passion_Cheese_21 = Passion_Cheese21.groupby('Product Name')['Approx. Total Revenue(INR)'].sum().reset_index()
Passion_Cheese_21

# Calculate the total sales for Passion Cheese products in 2021.
total_sale_Passion_Cheese_21 = Passion_Cheese21['Approx. Total Revenue(INR)'].sum()

# Filter the Passion Cheese data for the year 2022.
Passion_Cheese22 = Passion_Cheese[Passion_Cheese['Year'] == 2022]

# Group the 2022 Passion Cheese data by 'Product Name' and calculate the sum of 'Approx. Total Revenue(INR)'.
Passion_Cheese_22 = Passion_Cheese22.groupby('Product Name')['Approx. Total Revenue(INR)'].sum().reset_index()
Passion_Cheese_22

# Calculate the total sales for Passion Cheese products in 2022.
total_sale_Passion_Cheese_22 = Passion_Cheese22['Approx. Total Revenue(INR)'].sum()

# Merge the sales data for Passion Cheese products in 2019 and 2020 based on 'Product Name'.
Passion_Cheese_sale_19_20 = pd.merge(Passion_Cheese_19, Passion_Cheese_20, how='inner', left_on='Product Name', right_on='Product Name')

# Rename columns to indicate sales for 2019 and 2020.
Passion_Cheese_sale_19_20 = Passion_Cheese_sale_19_20.rename(columns={'Approx. Total Revenue(INR)_x': 'sale_2019', 'Approx. Total Revenue(INR)_y': 'sale_2020'})

# Merge the sales data for Passion Cheese products in 2021 and 2022 based on 'Product Name'.
Passion_Cheese_sale_21_22 = pd.merge(Passion_Cheese_21, Passion_Cheese_22, how='inner', left_on='Product Name', right_on='Product Name')

# Rename columns to indicate sales for 2021 and 2022.
Passion_Cheese_sale_21_22 = Passion_Cheese_sale_21_22.rename(columns={'Approx. Total Revenue(INR)_x': 'sale_2021', 'Approx. Total Revenue(INR)_y': 'sale_2022'})

# Merge the sales data for Passion Cheese products in 2019, 2020, 2021, and 2022 based on 'Product Name'.
Passion_Cheese_sale_19_20_21_22 = pd.merge(Passion_Cheese_sale_19_20, Passion_Cheese_sale_21_22, how='inner', left_on='Product Name', right_on='Product Name')

# Display the resulting DataFrame that contains sales data for Passion Cheese products in different years.
Passion_Cheese_sale_19_20_21_22
# Out:
#   Product Name  sale_2019  sale_2020  sale_2021  sale_2022
# 0       Cheese  514504.19   317955.3  351935.87  314257.79

# %%
# Years and total sales data for 'Warana' and 'Passion Cheese' products
years = [2019, 2020, 2021, 2022]
total_sales_warana = [total_sale_Warana_19, total_sale_Warana_20, total_sale_Warana_21, total_sale_Warana_22]
total_sales_passion_cheese = [total_sale_Passion_Cheese_19, total_sale_Passion_Cheese_20, total_sale_Passion_Cheese_21, total_sale_Passion_Cheese_22]

# Create a figure and axis
plt.figure(figsize=(10, 6))

# Plot a line chart for 'Warana' total sales
plt.plot(years, total_sales_warana, marker='o', label='Warana', linestyle='-', color='blue')

# Plot a line chart for 'Passion Cheese' total sales
plt.plot(years, total_sales_passion_cheese, marker='o', label='Passion Cheese', linestyle='-', color='orange')

# Add labels and title
plt.xlabel('Year')
plt.ylabel('Total Sales (INR)')
plt.title('Total Sales Comparison between "Warana" and "Passion Cheese" Products (2019-2022)')

# Set x-axis ticks and labels
plt.xticks(years)

# Show legend
plt.legend()

# Show gridlines
plt.grid(True)

# Display the line chart
plt.show()

# %% [markdown]
# # 10. How much year growth rate-Sales has been improved (CAGR) per location for all brand.

# %%
# Hint:.
# Filter the data to select rows where the 'Year' is 2019.
loc_19=dairy_data[dairy_data['Year'] == 2019]

# Group the 2019 data by 'Location' and calculate the sum of 'Approx. Total Revenue(INR)' for each location.
gr_loc_19=loc_19.groupby('Location')['Approx. Total Revenue(INR)'].sum().reset_index()

# Filter the data to select rows where the 'Year' is 2022.
loc_22=dairy_data[dairy_data['Year'] == 2022]

# Group the 2022 data by 'Location' and calculate the sum of 'Approx. Total Revenue(INR)' for each location.
gr_loc_22=loc_22.groupby('Location')['Approx. Total Revenue(INR)'].sum().reset_index()

# Merge the 2019 and 2022 location data based on 'Location'.
gr_loc_19_22=pd.merge(gr_loc_19,gr_loc_22,how='inner',left_on='Location',right_on='Location')

# Calculate the Compound Annual Growth Rate (CAGR) for each location's revenue from 2019 to 2022.
gr_loc_19_22['CAGR']=(((gr_loc_19_22['Approx. Total Revenue(INR)_y']/gr_loc_19_22['Approx. Total Revenue(INR)_x'])**1/3)-1)*100

# Display the resulting DataFrame that contains location-wise revenue and CAGR information.
gr_loc_19_22.sort_values('CAGR', ascending = False).round(2)
# Out:
#           Location  Approx. Total Revenue(INR)_x  \
# 6        Karnataka                     719961.89
# 8   Madhya Pradesh                     753779.95
# 9      Maharashtra                     785422.96
# 7           Kerala                    1038374.05
# 1       Chandigarh                    1898260.08
# 12       Telangana                     858617.44
# 4          Haryana                     815906.33
# 2            Delhi                    1742418.54
# 11      Tamil Nadu                     844111.97
# 3          Gujarat                     874497.67
# 10       Rajasthan                     997202.36
# 13   Uttar Pradesh                    1017058.94
# 5        Jharkhand                    1026918.25
# 14     West Bengal                     896961.25
# 0            Bihar                     968826.93
#
#     Approx. Total Revenue(INR)_y   CAGR
# 6                     1109077.78 -48.65
# 8                      917409.19 -59.43
# 9                      841929.32 -64.27
# ...
